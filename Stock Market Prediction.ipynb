# %%
import pandas as pd
import numpy as np
import quandl

# %%
BAC = quandl.get('WIKI/BAC',api_key='ioi9PN2b7b2yFziyESjB',start_date="2006-1-1",end_date="2016-1-1")

# %%
BAC
# Out:
#              Open   High    Low  Close      Volume  Ex-Dividend  Split Ratio  \
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700.0          0.0          1.0
# 2006-01-04  47.00  47.24  46.45  46.58  17757900.0          0.0          1.0
# 2006-01-05  46.58  46.83  46.32  46.64  14970700.0          0.0          1.0
# 2006-01-06  46.80  46.91  46.35  46.57  12599800.0          0.0          1.0
# 2006-01-09  46.72  46.97  46.36  46.60  15619400.0          0.0          1.0
# ...           ...    ...    ...    ...         ...          ...          ...
# 2015-12-24  17.32  17.38  17.22  17.27  29373415.0          0.0          1.0
# 2015-12-28  17.22  17.23  16.98  17.13  41759993.0          0.0          1.0
# 2015-12-29  17.25  17.35  17.16  17.28  45628449.0          0.0          1.0
# 2015-12-30  17.20  17.24  17.04  17.05  35035518.0          0.0          1.0
# 2015-12-31  17.01  17.07  16.83  16.83  47106760.0          0.0          1.0
#
# ...

# %%
C = quandl.get('WIKI/C',api_key='ioi9PN2b7b2yFziyESjB',start_date="2006-1-1",end_date="2016-1-1")

# %%
GS = quandl.get('WIKI/GS',api_key='ioi9PN2b7b2yFziyESjB',start_date="2006-1-1",end_date="2016-1-1")

# %%
JPM = quandl.get('WIKI/JPM',api_key='ioi9PN2b7b2yFziyESjB',start_date="2006-1-1",end_date="2016-1-1")

# %%
MS = quandl.get('WIKI/MS',api_key='ioi9PN2b7b2yFziyESjB',start_date="2006-1-1",end_date="2016-1-1")

# %%
WFC = quandl.get('WIKI/WFC',api_key='ioi9PN2b7b2yFziyESjB',start_date="2006-1-1",end_date="2016-1-1")

# %%
BAC = BAC[['Open', 'High','Low', 'Close','Volume']]

# %%
C = C[['Open', 'High','Low', 'Close','Volume']]

# %%
GS = GS[['Open', 'High','Low', 'Close','Volume']]

# %%
JPM = JPM[['Open', 'High','Low', 'Close','Volume']]

# %%
MS = MS[['Open', 'High','Low', 'Close','Volume']]

# %%
WFC = WFC[['Open', 'High','Low', 'Close','Volume']]

# %%
C
# Out:
#              Open   High    Low  Close      Volume
# Date
# 2006-01-03  49.00  49.38  48.11  49.29  15376000.0
# 2006-01-04  48.86  49.10  48.35  48.38  18709000.0
# 2006-01-05  48.44  48.78  48.40  48.62  11431000.0
# 2006-01-06  48.88  48.90  48.20  48.62  13702000.0
# 2006-01-09  48.60  48.74  48.30  48.39  16807000.0
# ...           ...    ...    ...    ...         ...
# 2015-12-24  52.48  52.97  52.45  52.71   4671254.0
# 2015-12-28  52.57  52.57  51.96  52.38   8760444.0
# 2015-12-29  52.76  53.22  52.74  52.98  10153534.0
# 2015-12-30  52.84  52.94  52.25  52.30   8763137.0
# 2015-12-31  52.07  52.39  51.75  51.75  11274831.0
#
# [2517 rows x 5 columns]

# %%
GS
# Out:
#               Open      High       Low   Close     Volume
# Date
# 2006-01-03  126.70  129.4400  124.2300  128.87  6188700.0
# 2006-01-04  127.35  128.9100  126.3800  127.09  4861600.0
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (BAC, Open)    2517 non-null   float64
#  1   (BAC, High)    2517 non-null   float64
#  2   (BAC, Low)     2517 non-null   float64
#  3   (BAC, Close)   2517 non-null   float64
#  4   (BAC, Volume)  2517 non-null   float64
#  5   (C, Open)      2517 non-null   float64
#  6   (C, High)      2517 non-null   float64
#  7   (C, Low)       2517 non-null   float64
#  8   (C, Close)     2517 non-null   float64
#  9   (C, Volume)    2517 non-null   float64
#  10  (GS, Open)     2517 non-null   float64
#  11  (GS, High)     2517 non-null   float64
#  12  (GS, Low)      2517 non-null   float64
#  13  (GS, Close)    2517 non-null   float64
#  14  (GS, Volume)   2517 non-null   float64
#  15  (JPM, Open)    2517 non-null   float64
# ...

# %%
bank_stocks['BAC']['Close']
# Out:
# Date
# 2006-01-03    47.08
# 2006-01-04    46.58
# 2006-01-05    46.64
# 2006-01-06    46.57
# 2006-01-09    46.60
#               ...
# 2015-12-24    17.27
# 2015-12-28    17.13
# 2015-12-29    17.28
# 2015-12-30    17.05
# 2015-12-31    16.83
# Name: Close, Length: 2517, dtype: float64

# %%
bank_stocks['BAC']['Close'].max()
# Out:
# 54.9

# %%
for tick in tickers:
    print(str(tick)+":"+str(bank_stocks[tick]['Close'].max()))
# Out:
# BAC:54.9
# C:60.34
# GS:247.92
# JPM:70.08
# MS:89.3
# WFC:73.0

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.90
# C       60.34
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     73.00
# dtype: float64

# %%
returnsDf = pd.DataFrame()

for tick in tickers:
    returnsDf[tick + 'Return'] = bank_stocks[tick]['Close'].pct_change()
    
returnsDf.head()
# Out:
#             BACReturn   CReturn  GSReturn  JPMReturn  MSReturn  WFCReturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN        NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686  -0.011599
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742  -0.001110
# 2006-01-06  -0.001501  0.000000  0.014169   0.007046  0.001025   0.005874
# 2006-01-09   0.000644 -0.004731  0.012030   0.016242  0.010586  -0.000158

# %%
import seaborn as sns

sns.pairplot(returnsDf[1:])

# %%
returnsDf.idxmin()
# Out:
# BACReturn   2009-01-20
# CReturn     2009-02-27
# GSReturn    2009-01-20
# JPMReturn   2009-01-20
# MSReturn    2008-10-09
# WFCReturn   2006-08-14
# dtype: datetime64[ns]

# %%
returnsDf.idxmax()
# Out:
# BACReturn   2009-04-09
# CReturn     2011-05-09
# GSReturn    2008-11-24
# JPMReturn   2009-01-21
# MSReturn    2008-10-13
# WFCReturn   2008-07-16
# dtype: datetime64[ns]

# %%
returnsDf.std()
# Out:
# BACReturn    0.036628
# CReturn      0.179066
# GSReturn     0.025358
# JPMReturn    0.027651
# MSReturn     0.037820
# WFCReturn    0.031838
# dtype: float64

# %%
returnsDf.loc['2015-12-31' : '2015-01-01'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 0 entries
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BACReturn  0 non-null      float64
#  1   CReturn    0 non-null      float64
#  2   GSReturn   0 non-null      float64
#  3   JPMReturn  0 non-null      float64
#  4   MSReturn   0 non-null      float64
#  5   WFCReturn  0 non-null      float64
# dtypes: float64(6)
# memory usage: 0.0 bytes

# %%
returnsDf.loc['2015-01-01' : '2015-12-31'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 252 entries, 2015-01-02 to 2015-12-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BACReturn  252 non-null    float64
#  1   CReturn    252 non-null    float64
#  2   GSReturn   252 non-null    float64
#  3   JPMReturn  252 non-null    float64
#  4   MSReturn   252 non-null    float64
#  5   WFCReturn  252 non-null    float64
# dtypes: float64(6)
# memory usage: 13.8 KB

# %%
returnsDf.loc['2015-01-01' : '2015-12-31'].std()
# Out:
# BACReturn    0.016163
# CReturn      0.015289
# GSReturn     0.014046
# JPMReturn    0.014017
# MSReturn     0.016249
# WFCReturn    0.012591
# dtype: float64

# %%
returnsDf2015 = returnsDf.loc['2015-01-01' : '2015-12-31']

returnsDf2015.isna()
# Out:
#             BACReturn  CReturn  GSReturn  JPMReturn  MSReturn  WFCReturn
# Date
# 2015-01-02      False    False     False      False     False      False
# 2015-01-05      False    False     False      False     False      False
# 2015-01-06      False    False     False      False     False      False
# 2015-01-07      False    False     False      False     False      False
# 2015-01-08      False    False     False      False     False      False
# ...               ...      ...       ...        ...       ...        ...
# 2015-12-24      False    False     False      False     False      False
# 2015-12-28      False    False     False      False     False      False
# 2015-12-29      False    False     False      False     False      False
# 2015-12-30      False    False     False      False     False      False
# 2015-12-31      False    False     False      False     False      False
#
# [252 rows x 6 columns]

# %%
returnsDf2015 = returnsDf2015[1:]

sns.distplot(returnsDf2015['MSReturn'])

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot()

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(figsize=(12,4))

# %%
import matplotlib.pyplot as plt

for tick in tickers:
    bank_stocks[tick]['Close'].plot(figsize=(12,4))
    
plt.legend()

# %%
import matplotlib.pyplot as plt

for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick, figsize=(12,4))
    
plt.legend()

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode,plot, iplot

init_notebook_mode(connected=True)

import cufflinks as cf

cf.go_offline()

bank_stocks.xs(key='Close', axis = 1, level='Stock Info').iplot()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
BAC_close_2018 = BAC['Close'].loc['2008-01-01' : '2009-01-01']

type(BAC_close_2018)
# Out:
# pandas.core.series.Series

# %%
BAC_close_2018.rolling(window=30).mean().plot(figsize=(12,4), label='30 Day Moving Average')
plt.legend()

# %%
BAC_close_2018.rolling(window=30).mean().plot(figsize=(12,4), label='30 Day Moving Average')
BAC_close_2018.plot(label='BAC Close')
plt.legend()

# %%
forHeatMap = bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr()
forHeatMap
# Out:
# Bank Ticker       BAC         C        GS       JPM        MS       WFC
# Bank Ticker
# BAC          1.000000  0.363303  0.550936  0.103855  0.944219  0.276687
# C            0.363303  1.000000  0.426868  0.700735  0.449794  0.723474
# GS           0.550936  0.426868  1.000000  0.685347  0.683830  0.359021
# JPM          0.103855  0.700735  0.685347  1.000000  0.250410  0.697574
# MS           0.944219  0.449794  0.683830  0.250410  1.000000  0.331510
# WFC          0.276687  0.723474  0.359021  0.697574  0.331510  1.000000

# %%
sns.heatmap(forHeatMap)

# %%
sns.heatmap(forHeatMap,annot = True)

# %%
sns.clustermap(forHeatMap, annot = True)

# %%
bac15 = BAC[['Open','High','Low','Close']].loc['2015-01-01' : '2016-01-01']
bac15.iplot(kind='candle')
# Out:
# <div>
#
#
#             <div id="c2bc16b3-3091-48d6-92aa-95aeef793ea8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c2bc16b3-3091-48d6-92aa-95aeef793ea8")) {
#                     Plotly.newPlot(
#                         'c2bc16b3-3091-48d6-92aa-95aeef793ea8',
# ...

# %%
MS['Close'].loc['2015-01-01' : '2016-01-01' ].ta_plot(study='sma', periods=[13, 21, 55])
# Out:
# <div>
#
#
#             <div id="9ec4a26a-7a17-4b1d-9ceb-462ed59a0211" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9ec4a26a-7a17-4b1d-9ceb-462ed59a0211")) {
#                     Plotly.newPlot(
#                         '9ec4a26a-7a17-4b1d-9ceb-462ed59a0211',
# ...

# %%
MS['Close'].loc['2015-01-01' : '2016-01-01' ].ta_plot(study='boll')
# Out:
# <div>
#
#
#             <div id="7be79c77-6838-47d9-91cf-fda2f51fa49e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7be79c77-6838-47d9-91cf-fda2f51fa49e")) {
#                     Plotly.newPlot(
#                         '7be79c77-6838-47d9-91cf-fda2f51fa49e',
# ...
